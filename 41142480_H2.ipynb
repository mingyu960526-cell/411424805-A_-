# %% [markdown]
# <a href="https://colab.research.google.com/github/mingyu960526-cell/411424805-A_-/blob/main/41142480_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("請輸入數字:"))
print(type(x))
# Out:
# 請輸入數字:4
# <class 'int'>

# %%
x=int(input("請輸入目前金幣數量:"))
y=int(input("請輸入獲得金幣數量:"))
sum=x+y
print(f"任務完成！你現在有{sum}枚金幣")
# Out:
# 請輸入目前金幣數量:250
# 請輸入獲得金幣數量:500
# 任務完成！你現在有750枚金幣

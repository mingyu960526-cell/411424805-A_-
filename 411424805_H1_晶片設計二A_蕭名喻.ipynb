# %% [markdown]
# <a href="https://colab.research.google.com/github/mingyu960526-cell/411424805-A_-/blob/main/411424805_H1_%E6%99%B6%E7%89%87%E8%A8%AD%E8%A8%88%E4%BA%8CA_%E8%95%AD%E5%90%8D%E5%96%BB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HI")
# Out:
# HI

# %%
print("2026","09",sep="/")
# Out:
# 2026/09

# %%
a=5
b=2.5
c="pthon"
print(type(c))
# Out:
# <class 'str'>

# %%
x=6
y=7
flag=x
x=y
y=flag
print(x,y)
# Out:
# 7 6

# %%
a=5
print(id(a))
# Out:
# 10446536

# %%
X=50000
rate=0.015
n=5
total=X*(1+0.015)**n
print(total)
# Out:
# 53864.20019421873

# %%
X=50000
rate=0.015
n=5
total=X*pow(1+0.015,n)
print(total)
# Out:
# 53864.20019421873
